# %%
import tkinter as tk
from tkinter import messagebox

# =====================
# FULL EMPLOYEE DATA
# =====================
employees = [
    {"EmployeeID":"GIG001","Name":"Chukwuemeka Okafor","Department":"Operations","Role":"Operations Manager","Email":"c.okafor@giglogistics.com","Phone":"8031234567","Location":"Lagos"},
    {"EmployeeID":"GIG002","Name":"Adaeze Nwosu","Department":"Operations","Role":"Dispatch Officer","Email":"a.nwosu@giglogistics.com","Phone":"8031234568","Location":"Lagos"},
    {"EmployeeID":"GIG003","Name":"Tunde Adeleke","Department":"Operations","Role":"Logistics Coordinator","Email":"t.adeleke@giglogistics.com","Phone":"8031234569","Location":"Abuja"},
    {"EmployeeID":"GIG004","Name":"Ngozi Eze","Department":"Operations","Role":"Fleet Supervisor","Email":"n.eze@giglogistics.com","Phone":"8031234570","Location":"Lagos"},
    {"EmployeeID":"GIG005","Name":"Emeka Chukwu","Department":"Operations","Role":"Route Planner","Email":"e.chukwu@giglogistics.com","Phone":"8031234571","Location":"Port Harcourt"},
    {"EmployeeID":"GIG006","Name":"Fatima Bello","Department":"Operations","Role":"Warehouse Officer","Email":"f.bello@giglogistics.com","Phone":"8031234572","Location":"Kano"},
    {"EmployeeID":"GIG007","Name":"Seun Adesanya","Department":"Operations","Role":"Delivery Agent","Email":"s.adesanya@giglogistics.com","Phone":"8031234573","Location":"Lagos"},
    {"EmployeeID":"GIG008","Name":"Kelechi Onyekachi","Department":"Operations","Role":"Delivery Agent","Email":"k.onyekachi@giglogistics.com","Phone":"8031234574","Location":"Enugu"},
    {"EmployeeID":"GIG009","Name":"Hauwa Musa","Department":"Finance","Role":"Chief Finance Officer","Email":"h.musa@giglogistics.com","Phone":"8031234575","Location":"Abuja"},
    {"EmployeeID":"GIG010","Name":"Rotimi Adeyemi","Department":"Finance","Role":"Accountant","Email":"r.adeyemi@giglogistics.com","Phone":"8031234576","Location":"Lagos"},
    {"EmployeeID":"GIG011","Name":"Chioma Obi","Department":"Finance","Role":"Budget Analyst","Email":"c.obi@giglogistics.com","Phone":"8031234577","Location":"Lagos"},
    {"EmployeeID":"GIG012","Name":"Yusuf Garba","Department":"Finance","Role":"Accounts Officer","Email":"y.garba@giglogistics.com","Phone":"8031234578","Location":"Kano"},
    {"EmployeeID":"GIG013","Name":"Blessing Okoro","Department":"Finance","Role":"Payroll Officer","Email":"b.okoro@giglogistics.com","Phone":"8031234579","Location":"Port Harcourt"},
    {"EmployeeID":"GIG014","Name":"Taiwo Akinwale","Department":"Finance","Role":"Internal Auditor","Email":"t.akinwale@giglogistics.com","Phone":"8031234580","Location":"Ibadan"},
    {"EmployeeID":"GIG015","Name":"Amina Usman","Department":"Human Resources","Role":"HR Manager","Email":"a.usman@giglogistics.com","Phone":"8031234581","Location":"Abuja"},
    {"EmployeeID":"GIG016","Name":"Ifeanyi Okonkwo","Department":"Human Resources","Role":"Recruitment Officer","Email":"i.okonkwo@giglogistics.com","Phone":"8031234582","Location":"Lagos"},
    {"EmployeeID":"GIG017","Name":"Sade Fashola","Department":"Human Resources","Role":"Training Coordinator","Email":"s.fashola@giglogistics.com","Phone":"8031234583","Location":"Lagos"},
    {"EmployeeID":"GIG018","Name":"Nnamdi Okeke","Department":"Human Resources","Role":"HR Assistant","Email":"n.okeke@giglogistics.com","Phone":"8031234584","Location":"Enugu"},
    {"EmployeeID":"GIG019","Name":"Maryam Abdullahi","Department":"Human Resources","Role":"Employee Relations Officer","Email":"m.abdullahi@giglogistics.com","Phone":"8031234585","Location":"Abuja"},
    {"EmployeeID":"GIG020","Name":"Oluwaseun Balogun","Department":"Technology","Role":"Head of Technology","Email":"o.balogun@giglogistics.com","Phone":"8031234586","Location":"Lagos"},
    {"EmployeeID":"GIG021","Name":"Chidi Nwachukwu","Department":"Technology","Role":"Software Developer","Email":"c.nwachukwu@giglogistics.com","Phone":"8031234587","Location":"Lagos"},
    {"EmployeeID":"GIG022","Name":"Aisha Lawal","Department":"Technology","Role":"Data Analyst","Email":"a.lawal@giglogistics.com","Phone":"8031234588","Location":"Abuja"},
    {"EmployeeID":"GIG023","Name":"Gbenga Adebisi","Department":"Technology","Role":"IT Support Engineer","Email":"g.adebisi@giglogistics.com","Phone":"8031234589","Location":"Lagos"},
    {"EmployeeID":"GIG024","Name":"Nneka Oduya","Department":"Technology","Role":"Systems Administrator","Email":"n.oduya@giglogistics.com","Phone":"8031234590","Location":"Port Harcourt"},
    {"EmployeeID":"GIG025","Name":"Ibrahim Suleiman","Department":"Technology","Role":"Cybersecurity Analyst","Email":"i.suleiman@giglogistics.com","Phone":"8031234591","Location":"Abuja"},
    {"EmployeeID":"GIG026","Name":"Tolulope Ogunwale","Department":"Customer Service","Role":"Customer Service Manager","Email":"t.ogunwale@giglogistics.com","Phone":"8031234592","Location":"Lagos"},
    {"EmployeeID":"GIG027","Name":"Esther Aniemeka","Department":"Customer Service","Role":"Customer Support Officer","Email":"e.aniemeka@giglogistics.com","Phone":"8031234593","Location":"Lagos"},
    {"EmployeeID":"GIG028","Name":"Biodun Ojo","Department":"Customer Service","Role":"Customer Support Officer","Email":"b.ojo@giglogistics.com","Phone":"8031234594","Location":"Ibadan"},
    {"EmployeeID":"GIG029","Name":"Rukayat Folarin","Department":"Customer Service","Role":"Complaints Resolution Officer","Email":"r.folarin@giglogistics.com","Phone":"8031234595","Location":"Lagos"},
    {"EmployeeID":"GIG030","Name":"Chinedu Obiora","Department":"Customer Service","Role":"Call Centre Agent","Email":"c.obiora@giglogistics.com","Phone":"8031234596","Location":"Enugu"},
    {"EmployeeID":"GIG031","Name":"Damilola Akintola","Department":"Sales","Role":"Sales Manager","Email":"d.akintola@giglogistics.com","Phone":"8031234597","Location":"Lagos"},
    {"EmployeeID":"GIG032","Name":"Uche Okereke","Department":"Sales","Role":"Business Development Officer","Email":"u.okereke@giglogistics.com","Phone":"8031234598","Location":"Port Harcourt"},
    {"EmployeeID":"GIG033","Name":"Zainab Idris","Department":"Sales","Role":"Key Account Manager","Email":"z.idris@giglogistics.com","Phone":"8031234599","Location":"Kano"},
    {"EmployeeID":"GIG034","Name":"Femi Adeyinka","Department":"Sales","Role":"Sales Executive","Email":"f.adeyinka@giglogistics.com","Phone":"8031234600","Location":"Lagos"},
    {"EmployeeID":"GIG035","Name":"Precious Igwe","Department":"Sales","Role":"Sales Executive","Email":"p.igwe@giglogistics.com","Phone":"8031234601","Location":"Owerri"},
    {"EmployeeID":"GIG036","Name":"Lara Oduola","Department":"Marketing","Role":"Marketing Manager","Email":"l.oduola@giglogistics.com","Phone":"8031234602","Location":"Lagos"},
    {"EmployeeID":"GIG037","Name":"Tochukwu Eze","Department":"Marketing","Role":"Digital Marketing Officer","Email":"t.eze@giglogistics.com","Phone":"8031234603","Location":"Lagos"},
    {"EmployeeID":"GIG038","Name":"Hadiza Yakubu","Department":"Marketing","Role":"Brand Officer","Email":"h.yakubu@giglogistics.com","Phone":"8031234604","Location":"Abuja"},
    {"EmployeeID":"GIG039","Name":"Victor Osemeka","Department":"Marketing","Role":"Content Creator","Email":"v.osemeka@giglogistics.com","Phone":"8031234605","Location":"Lagos"},
    {"EmployeeID":"GIG040","Name":"Chidinma Nwofor","Department":"Marketing","Role":"Social Media Manager","Email":"c.nwofor@giglogistics.com","Phone":"8031234606","Location":"Lagos"}
]

# =====================
# BUTTON FUNCTIONS
# =====================
def submit():
    username_input = name_entry.get().strip()
    username = username_input.lower()
    department = dept_var.get()

    if username_input == "":
        messagebox.showerror("Error", "Please enter a name")
        return
    if department == "Select Department":
        messagebox.showerror("Error", "Please select a department")
        return

    found = False
    colleagues = []

    for emp in employees:
        if emp["Department"] == department:
            colleagues.append(emp["Name"])
        if emp["Name"].lower() == username and emp["Department"] == department:
            found = True

    if found:
        welcomeMessage(username_input, department, colleagues)
    else:
        messagebox.showerror("Error", "Employee does not exist")

def welcomeMessage(name, department, colleagues):
    window = tk.Toplevel(root)
    window.title("Employee Verified")
    window.geometry("400x300")

    tk.Label(window, text=f"Welcome {name}", font=("Arial", 14)).pack(pady=5)
    tk.Label(window, text=f"Department: {department}").pack(pady=5)
    tk.Label(window, text="Colleagues:").pack()

    listbox = tk.Listbox(window)
    listbox.pack(pady=10, fill="both", expand=True)

    for person in colleagues:
        if person.lower() != name.lower():
            listbox.insert(tk.END, person)

def clear_fields():
    name_entry.delete(0, tk.END)
    dept_var.set("Select Department")

# =====================
# GUI SETUP
# =====================
root = tk.Tk()
root.title("GIG Logistics Verification")
root.geometry("400x250")

tk.Label(root, text="Enter Name:").pack(pady=5)
name_entry = tk.Entry(root)
name_entry.pack(pady=5)

tk.Label(root, text="Select Department:").pack(pady=5)
dept_var = tk.StringVar()
dept_var.set("Select Department")

departments = [
    "Operations",
    "Finance",
    "Human Resources",
    "Technology",
    "Customer Service",
    "Sales",
    "Marketing"
]

dropdown = tk.OptionMenu(root, dept_var, *departments)
dropdown.pack(pady=5)

tk.Button(root, text="Submit", command=submit).pack(pady=5)
tk.Button(root, text="Clear", command=clear_fields).pack(pady=5)

root.mainloop()
