# %%
c.Algorithm: Swap Ages of Two People

1.START

2.Input Name1

3.Input Age1

4.Input Name2

5.Input Age2

6.Set Temp = Age1

7.Set Age1 = Age2

8.Set Age2 = Temp

9.Display Name1 and new Age1

10.Display Name2 and new Age2

11.END

Cli
