# %%
A.#project 1
#store checkout after purchase

START
Initialize total price
Scan items
Add item prices to total
Check if more items exist
Display total price
Receive payment
Check if payment is enough
If yes -> print receipt and give change
If nbo -> request additional payment
END
